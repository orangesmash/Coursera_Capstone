# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 12.8MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0" (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/36/69/d82d04022f02733bf9a72bc3b96332d360c0c5307096d76f6bb7489f7e57/soupsieve-2.2.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.2.1

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/e1/e1/45f25e3d3acf26782888f847de7c958a2807a039210fb1016cc3fb9555c4/geopy-2.2.0-py3-none-any.whl (118kB)
#      |████████████████████████████████| 122kB 21.1MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/df/60/d1d4c4944f9726228faa80fbe2206c8ddfd9757791b2de2facb8818c5d74/geographiclib-1.52-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import json # library to handle JSON files

# Import for Foursquare location identification
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images for Foursquare
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# ! pip install folium==0.5.0- already installed
import folium # plotting library

print('Folium imported')
print('Libraries imported.')

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Matplotlib Libraries imported.')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Folium imported
# Libraries imported.
# Matplotlib Libraries imported.

# %%
#Foursquare API credentials

CLIENT_ID = 'E5I51B3VB22JC2UVGFPLOYM0OCTN24L4G1G5WXSZZ0LFJLT4' # your Foursquare ID
CLIENT_SECRET = 'M4FLBKTWSGLUDPSCGFP35QKCTJRFFKK24ZCBVO5KHC4ZOGOV' # your Foursquare Secret
ACCESS_TOKEN = 'D4SVAO3X5B2LMMDFCEUSFQFIIKHKAHQFD5QTWOAXNIUKQ24X' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: E5I51B3VB22JC2UVGFPLOYM0OCTN24L4G1G5WXSZZ0LFJLT4
# CLIENT_SECRET:M4FLBKTWSGLUDPSCGFP35QKCTJRFFKK24ZCBVO5KHC4ZOGOV

# %%
#Define a user_agent for the Singapore instance of the geocoder
address = 'Singapore'
geolocator = Nominatim(user_agent="singapore_explorer")
location = geolocator.geocode(address)
latitude_sg = location.latitude
longitude_sg = location.longitude
print(f'Geographical coordinates of Singapore: {latitude_sg}, {longitude_sg}.')
# Out:
# Geographical coordinates of Singapore: 1.357107, 103.8194992.

# %%
#Define a user_agent for the Hong Kong instance of the geocoder
address = 'Hong Kong'
geolocator = Nominatim(user_agent="hk_explorer")
location = geolocator.geocode(address)
latitude_sg = location.latitude
longitude_sg = location.longitude
print(f'Geographical coordinates of Hong Kong: {latitude}, {longitude}.')
# Out:
# Geographical coordinates of Hong Kong: 22.2793278, 114.1628131.

# %%
search_query = 'Halal'
radius = 10000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_sg, longitude_sg,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url

#Singapore halal search
#https://foursquare.com/explore?mode=url&near=Singapore%2C%20Singapore&nearGeoId=72057594039808188&q=halal
# Out:
# Halal .... OK!
# 'https://api.foursquare.com/v2/venues/search?client_id=E5I51B3VB22JC2UVGFPLOYM0OCTN24L4G1G5WXSZZ0LFJLT4&client_secret=M4FLBKTWSGLUDPSCGFP35QKCTJRFFKK24ZCBVO5KHC4ZOGOV&ll=1.357107,103.8194992&oauth_token=D4SVAO3X5B2LMMDFCEUSFQFIIKHKAHQFD5QTWOAXNIUKQ24X&v=20180604&query=Halal&radius=10000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '610e0886a4a98f07530510cb'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4cb944634c60a0934ef03eca',
#     'name': 'Air Pasang Nasi Campur & Halal Seafood',
#     'location': {'address': '374 Bukit Batok St. 31, #01-192',
#      'lat': 1.3576546171489323,
#      'lng': 103.75021960745524,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3576546171489323,
#        'lng': 103.75021960745524}],
#      'distance': 7710,
#      'postalCode': '650374',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['374 Bukit Batok St. 31, #01-192', '650374']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4c258a4bf1272d7f071d85c5',
#     'name': 'Sushi Hey - Halal',
#     'location': {'address': 'Sembawang Shopping Centre',
#      'lat': 1.367411601858592,
#      'lng': 103.82518375488131,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.367411601858592,
#        'lng': 103.82518375488131}],
#      'distance': 1309,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Sembawang Shopping Centre']},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4cf9b1c37f2db1f7490723d4',
#     'name': 'Chicken Rice Halal',
#     'location': {'address': 'Blk46-1 tanglin halt',
#      'lat': 1.2988465042583794,
#      'lng': 103.7981647681224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.2988465042583794,
#        'lng': 103.7981647681224}],
#      'distance': 6906,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Blk46-1 tanglin halt']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4cfb5c40ee9cb60ce0f48fad',
#     'name': 'Cahaya Murni Halal Muslim Food',
#     'location': {'address': '#05-91/92, Far East Plaza',
#      'crossStreet': '14 Scotts Rd',
#      'lat': 1.307398869751881,
#      'lng': 103.83336060292754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.307398869751881,
#        'lng': 103.83336060292754}],
#      'distance': 5744,
#      'postalCode': '228213',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#05-91/92, Far East Plaza (14 Scotts Rd)',
#       '228213']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'shortName': 'Halal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d3969a0687ca35da50a7fc4',
#     'name': 'Kedai Kopi Halal Cafe',
#     'location': {'address': 'IMM Building',
#      'crossStreet': '2 Jurong East St. 21',
#      'lat': 1.3351751581275573,
#      'lng': 103.74720282357907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3351751581275573,
#        'lng': 103.74720282357907}],
#      'distance': 8407,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['IMM Building (2 Jurong East St. 21)']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '53a388b3498e92f6ecde8307',
#     'name': 'Global Halal Hub',
#     'location': {'address': '750 #01-07',
#      'crossStreet': 'Viva Business Park',
#      'lat': 1.3326057161386595,
#      'lng': 103.8911347630843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3326057161386595,
#        'lng': 103.8911347630843}],
#      'distance': 8425,
#      'postalCode': '469000',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['750 #01-07 (Viva Business Park)', '469000']},
#     'categories': [{'id': '52e816a6bcbc57f1066b7a54',
#       'name': 'Warehouse Store',
#       'pluralName': 'Warehouse Stores',
#       'shortName': 'Warehouse Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4bc0153d920eb7130e91182c',
#     'name': 'Os Halal Food',
#     'location': {'address': '101 Bedok Reservoir Road',
#      'lat': 1.333445992672062,
#      'lng': 103.90930296406043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.333445992672062,
#        'lng': 103.90930296406043}],
#      'distance': 10335,
#      'postalCode': '470101',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['101 Bedok Reservoir Road', '470101']},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d5cad919c31b60c59b9b7ee',
#     'name': 'Happy Family Pasta & Pizza (halal)',
#     'location': {'address': 'Toa Payoh lorong 2, above wet market #02-39',
#      'lat': 1.33825,
#      'lng': 103.844749,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.33825,
#        'lng': 103.844749}],
#      'distance': 3507,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['Toa Payoh lorong 2, above wet market #02-39']},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '54c88b6e498e5fd8bb51450d',
#     'name': 'Halal Guy,NY',
#     'location': {'lat': 1.320566,
#      'lng': 103.842553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.320566,
#        'lng': 103.842553}],
#      'distance': 4809,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '5104ad75e4b073eb9b199318',
#     'name': 'Sakura Halal Food*',
#     'location': {'lat': 1.3176064739367392,
#      'lng': 103.82573283698129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3176064739367392,
#        'lng': 103.82573283698129}],
#      'distance': 4451,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d648d44823ca35d9470f588',
#     'name': 'Halal Nasi Padang Coffeeshop',
#     'location': {'lat': 1.3175669822652758,
#      'lng': 103.84351999248658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3175669822652758,
#        'lng': 103.84351999248658}],
#      'distance': 5149,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4ecdc716f790d070358362ff',
#     'name': 'Halal Zone',
#     'location': {'lat': 1.3755665156761359,
#      'lng': 103.87235064647466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3755665156761359,
#        'lng': 103.87235064647466}],
#      'distance': 6230,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4cb691f58db0a143cd2c6b16',
#     'name': 'A-la Mak Halal Menu',
#     'location': {'lat': 1.386452,
#      'lng': 103.829315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.386452,
#        'lng': 103.829315}],
#      'distance': 3444,
#      'postalCode': '787571',
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['787571']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4ef309f25c5cd8c3b324c0cf',
#     'name': 'Halal Thai Chinese',
#     'location': {'address': 'Far East Plaza',
#      'lat': 1.306253548775494,
#      'lng': 103.83442221589266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.306253548775494,
#        'lng': 103.83442221589266}],
#      'distance': 5899,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Far East Plaza']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '5c4b083cb6eedb002cc59f92',
#     'name': 'Halal Hot & Cold Drinks',
#     'location': {'address': '#01-06, Yishun Park Hawker Centre',
#      'crossStreet': '51 Yishun Avenue 11',
#      'lat': 1.424577,
#      'lng': 103.845022,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.424577,
#        'lng': 103.845022}],
#      'distance': 8029,
#      'cc': 'SG',
#      'neighborhood': 'Yishun',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#01-06, Yishun Park Hawker Centre (51 Yishun Avenue 11)']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4e2254b952b1f82ffba8a533',
#     'name': 'Halal Foods International',
#     'location': {'lat': 1.3072826764511076,
#      'lng': 103.85143463087644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3072826764511076,
#        'lng': 103.85143463087644}],
#      'distance': 6587,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4de98c4445dd3993a874e5e5',
#     'name': 'Halal Muslim Food',
#     'location': {'lat': 1.361233,
#      'lng': 103.74759,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.361233,
#        'lng': 103.74759}],
#      'distance': 8015,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore'},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d522b76bd6ff04d8e5cf90c',
#     'name': 'Daging Dendeng Halal Sedap',
#     'location': {'lat': 1.3893474550888771,
#      'lng': 103.80872930740412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3893474550888771,
#        'lng': 103.80872930740412}],
#      'distance': 3783,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d2973a03c795481621dd89b',
#     'name': 'Halal Seafood',
#     'location': {'address': 'Lau pa sat',
#      'lat': 1.280946,
#      'lng': 103.854189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.280946,
#        'lng': 103.854189}],
#      'distance': 9315,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Lau pa sat']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d7ee0c1b25d6dcb9bb5c242',
#     'name': 'Halal Goods International @ Quartz industrial Building',
#     'location': {'lat': 1.3333031666666668,
#      'lng': 103.88186653333332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3333031666666668,
#        'lng': 103.88186653333332}],
#      'distance': 7429,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4f27bdfde4b0cec78dbba56a',
#     'name': 'Halal Bbq Seafood @ Beach Rd',
#     'location': {'address': 'Beach Road',
#      'lat': 1.3013044773325562,
#      'lng': 103.85771928965431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3013044773325562,
#        'lng': 103.85771928965431}],
#      'distance': 7528,
#      'cc': 'SG',
#      'country': 'Singapore',
#      'formattedAddress': ['Beach Road']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4d57ac23de8f6dcb62e80191',
#     'name': 'Halal Cookhouse @ Khatib Camp',
#     'location': {'lat': 1.426283,
#      'lng': 103.827826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.426283,
#        'lng': 103.827826}],
#      'distance': 7756,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4cbaf1a6adcd548107ef25a2',
#     'name': 'Halal Cafe',
#     'location': {'lat': 1.3358417236156326,
#      'lng': 103.74693127090184,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3358417236156326,
#        'lng': 103.74693127090184}],
#      'distance': 8415,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4cb124feeb65b1f7f39372cd',
#     'name': 'Halal  Wet Market',
#     'location': {'address': 'lelong lelong',
#      'lat': 1.43678531,
#      'lng': 103.838882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.43678531,
#        'lng': 103.838882}],
#      'distance': 9128,
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['lelong lelong']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4f3c4f05e4b085c2d8999846',
#     'name': 'Fernvale butcher and poultry(Halal)',
#     'location': {'lat': 1.391811128657146,
#      'lng': 103.87759430918543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.391811128657146,
#        'lng': 103.87759430918543}],
#      'distance': 7531,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d11d951735',
#       'name': 'Butcher',
#       'pluralName': 'Butchers',
#       'shortName': 'Butcher',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '56e2940fcd10440088d5305a',
#     'name': 'Halal Frozen Food',
#     'location': {'lat': 1.3154757,
#      'lng': 103.89597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3154757,
#        'lng': 103.89597}],
#      'distance': 9690,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '56aa371be4b08b9a8d573550',
#       'name': 'Food Service',
#       'pluralName': 'Food Services',
#       'shortName': 'Food Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '59561b48033693555b46b641',
#     'name': 'Qtech Cafe Coffee & Tea Halal Restaurant',
#     'location': {'address': '211 Syed Alwi Road',
#      'lat': 1.3078441815854558,
#      'lng': 103.85762080550192,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3078441815854558,
#        'lng': 103.85762080550192}],
#      'distance': 6933,
#      'postalCode': '207744',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['211 Syed Alwi Road', '207744']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '429890913'},
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4c92f7fad2e1a1436938cf26',
#     'name': 'halal bakery',
#     'location': {'lat': 1.319245,
#      'lng': 103.89418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.319245,
#        'lng': 103.89418}],
#      'distance': 9318,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d1bc941735',
#       'name': 'Cupcake Shop',
#       'pluralName': 'Cupcake Shops',
#       'shortName': 'Cupcakes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '4faf29dee4b01cbf307ccd3f',
#     'name': 'Halal tcm',
#     'location': {'lat': 1.3176262635322167,
#      'lng': 103.89882017629914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.3176262635322167,
#        'lng': 103.89882017629914}],
#      'distance': 9861,
#      'cc': 'SG',
#      'country': 'Singapore'},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False},
#    {'id': '5871e0ea3731812c07bc6783',
#     'name': 'Noosh Halal Noodle Bar & Grill',
#     'location': {'address': '#01-13B Esplanade Mall',
#      'crossStreet': '8 Raffles Avenue',
#      'lat': 1.289529819986258,
#      'lng': 103.8565092792591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 1.289529819986258,
#        'lng': 103.8565092792591}],
#      'distance': 8576,
#      'postalCode': '039802',
#      'cc': 'SG',
#      'city': 'Singapore',
#      'country': 'Singapore',
#      'formattedAddress': ['#01-13B Esplanade Mall (8 Raffles Avenue)',
#       '039802']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'shortName': 'Halal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628309638',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
venues
# Out:
# [{'id': '4cb944634c60a0934ef03eca',
#   'name': 'Air Pasang Nasi Campur & Halal Seafood',
#   'location': {'address': '374 Bukit Batok St. 31, #01-192',
#    'lat': 1.3576546171489323,
#    'lng': 103.75021960745524,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3576546171489323,
#      'lng': 103.75021960745524}],
#    'distance': 7710,
#    'postalCode': '650374',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['374 Bukit Batok St. 31, #01-192', '650374']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4c258a4bf1272d7f071d85c5',
#   'name': 'Sushi Hey - Halal',
#   'location': {'address': 'Sembawang Shopping Centre',
#    'lat': 1.367411601858592,
#    'lng': 103.82518375488131,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.367411601858592,
#      'lng': 103.82518375488131}],
#    'distance': 1309,
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['Sembawang Shopping Centre']},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4cf9b1c37f2db1f7490723d4',
#   'name': 'Chicken Rice Halal',
#   'location': {'address': 'Blk46-1 tanglin halt',
#    'lat': 1.2988465042583794,
#    'lng': 103.7981647681224,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.2988465042583794,
#      'lng': 103.7981647681224}],
#    'distance': 6906,
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['Blk46-1 tanglin halt']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4cfb5c40ee9cb60ce0f48fad',
#   'name': 'Cahaya Murni Halal Muslim Food',
#   'location': {'address': '#05-91/92, Far East Plaza',
#    'crossStreet': '14 Scotts Rd',
#    'lat': 1.307398869751881,
#    'lng': 103.83336060292754,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.307398869751881,
#      'lng': 103.83336060292754}],
#    'distance': 5744,
#    'postalCode': '228213',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['#05-91/92, Far East Plaza (14 Scotts Rd)', '228213']},
#   'categories': [{'id': '52e81612bcbc57f1066b79ff',
#     'name': 'Halal Restaurant',
#     'pluralName': 'Halal Restaurants',
#     'shortName': 'Halal',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d3969a0687ca35da50a7fc4',
#   'name': 'Kedai Kopi Halal Cafe',
#   'location': {'address': 'IMM Building',
#    'crossStreet': '2 Jurong East St. 21',
#    'lat': 1.3351751581275573,
#    'lng': 103.74720282357907,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3351751581275573,
#      'lng': 103.74720282357907}],
#    'distance': 8407,
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['IMM Building (2 Jurong East St. 21)']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '53a388b3498e92f6ecde8307',
#   'name': 'Global Halal Hub',
#   'location': {'address': '750 #01-07',
#    'crossStreet': 'Viva Business Park',
#    'lat': 1.3326057161386595,
#    'lng': 103.8911347630843,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3326057161386595,
#      'lng': 103.8911347630843}],
#    'distance': 8425,
#    'postalCode': '469000',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['750 #01-07 (Viva Business Park)', '469000']},
#   'categories': [{'id': '52e816a6bcbc57f1066b7a54',
#     'name': 'Warehouse Store',
#     'pluralName': 'Warehouse Stores',
#     'shortName': 'Warehouse Store',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4bc0153d920eb7130e91182c',
#   'name': 'Os Halal Food',
#   'location': {'address': '101 Bedok Reservoir Road',
#    'lat': 1.333445992672062,
#    'lng': 103.90930296406043,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.333445992672062,
#      'lng': 103.90930296406043}],
#    'distance': 10335,
#    'postalCode': '470101',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['101 Bedok Reservoir Road', '470101']},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d5cad919c31b60c59b9b7ee',
#   'name': 'Happy Family Pasta & Pizza (halal)',
#   'location': {'address': 'Toa Payoh lorong 2, above wet market #02-39',
#    'lat': 1.33825,
#    'lng': 103.844749,
#    'labeledLatLngs': [{'label': 'display', 'lat': 1.33825, 'lng': 103.844749}],
#    'distance': 3507,
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['Toa Payoh lorong 2, above wet market #02-39']},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '54c88b6e498e5fd8bb51450d',
#   'name': 'Halal Guy,NY',
#   'location': {'lat': 1.320566,
#    'lng': 103.842553,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.320566,
#      'lng': 103.842553}],
#    'distance': 4809,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '5104ad75e4b073eb9b199318',
#   'name': 'Sakura Halal Food*',
#   'location': {'lat': 1.3176064739367392,
#    'lng': 103.82573283698129,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3176064739367392,
#      'lng': 103.82573283698129}],
#    'distance': 4451,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d10f941735',
#     'name': 'Indian Restaurant',
#     'pluralName': 'Indian Restaurants',
#     'shortName': 'Indian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d648d44823ca35d9470f588',
#   'name': 'Halal Nasi Padang Coffeeshop',
#   'location': {'lat': 1.3175669822652758,
#    'lng': 103.84351999248658,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3175669822652758,
#      'lng': 103.84351999248658}],
#    'distance': 5149,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4ecdc716f790d070358362ff',
#   'name': 'Halal Zone',
#   'location': {'lat': 1.3755665156761359,
#    'lng': 103.87235064647466,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3755665156761359,
#      'lng': 103.87235064647466}],
#    'distance': 6230,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d1ee931735',
#     'name': 'Hostel',
#     'pluralName': 'Hostels',
#     'shortName': 'Hostel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4cb691f58db0a143cd2c6b16',
#   'name': 'A-la Mak Halal Menu',
#   'location': {'lat': 1.386452,
#    'lng': 103.829315,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.386452,
#      'lng': 103.829315}],
#    'distance': 3444,
#    'postalCode': '787571',
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['787571']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4ef309f25c5cd8c3b324c0cf',
#   'name': 'Halal Thai Chinese',
#   'location': {'address': 'Far East Plaza',
#    'lat': 1.306253548775494,
#    'lng': 103.83442221589266,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.306253548775494,
#      'lng': 103.83442221589266}],
#    'distance': 5899,
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['Far East Plaza']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '5c4b083cb6eedb002cc59f92',
#   'name': 'Halal Hot & Cold Drinks',
#   'location': {'address': '#01-06, Yishun Park Hawker Centre',
#    'crossStreet': '51 Yishun Avenue 11',
#    'lat': 1.424577,
#    'lng': 103.845022,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.424577,
#      'lng': 103.845022}],
#    'distance': 8029,
#    'cc': 'SG',
#    'neighborhood': 'Yishun',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['#01-06, Yishun Park Hawker Centre (51 Yishun Avenue 11)']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4e2254b952b1f82ffba8a533',
#   'name': 'Halal Foods International',
#   'location': {'lat': 1.3072826764511076,
#    'lng': 103.85143463087644,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3072826764511076,
#      'lng': 103.85143463087644}],
#    'distance': 6587,
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d10f951735',
#     'name': 'Pharmacy',
#     'pluralName': 'Pharmacies',
#     'shortName': 'Pharmacy',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4de98c4445dd3993a874e5e5',
#   'name': 'Halal Muslim Food',
#   'location': {'lat': 1.361233,
#    'lng': 103.74759,
#    'labeledLatLngs': [{'label': 'display', 'lat': 1.361233, 'lng': 103.74759}],
#    'distance': 8015,
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore'},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d522b76bd6ff04d8e5cf90c',
#   'name': 'Daging Dendeng Halal Sedap',
#   'location': {'lat': 1.3893474550888771,
#    'lng': 103.80872930740412,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3893474550888771,
#      'lng': 103.80872930740412}],
#    'distance': 3783,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d2973a03c795481621dd89b',
#   'name': 'Halal Seafood',
#   'location': {'address': 'Lau pa sat',
#    'lat': 1.280946,
#    'lng': 103.854189,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.280946,
#      'lng': 103.854189}],
#    'distance': 9315,
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['Lau pa sat']},
#   'categories': [{'id': '4bf58dd8d48988d1ce941735',
#     'name': 'Seafood Restaurant',
#     'pluralName': 'Seafood Restaurants',
#     'shortName': 'Seafood',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d7ee0c1b25d6dcb9bb5c242',
#   'name': 'Halal Goods International @ Quartz industrial Building',
#   'location': {'lat': 1.3333031666666668,
#    'lng': 103.88186653333332,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3333031666666668,
#      'lng': 103.88186653333332}],
#    'distance': 7429,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4f27bdfde4b0cec78dbba56a',
#   'name': 'Halal Bbq Seafood @ Beach Rd',
#   'location': {'address': 'Beach Road',
#    'lat': 1.3013044773325562,
#    'lng': 103.85771928965431,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3013044773325562,
#      'lng': 103.85771928965431}],
#    'distance': 7528,
#    'cc': 'SG',
#    'country': 'Singapore',
#    'formattedAddress': ['Beach Road']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4d57ac23de8f6dcb62e80191',
#   'name': 'Halal Cookhouse @ Khatib Camp',
#   'location': {'lat': 1.426283,
#    'lng': 103.827826,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.426283,
#      'lng': 103.827826}],
#    'distance': 7756,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d147941735',
#     'name': 'Diner',
#     'pluralName': 'Diners',
#     'shortName': 'Diner',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4cbaf1a6adcd548107ef25a2',
#   'name': 'Halal Cafe',
#   'location': {'lat': 1.3358417236156326,
#    'lng': 103.74693127090184,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3358417236156326,
#      'lng': 103.74693127090184}],
#    'distance': 8415,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4cb124feeb65b1f7f39372cd',
#   'name': 'Halal  Wet Market',
#   'location': {'address': 'lelong lelong',
#    'lat': 1.43678531,
#    'lng': 103.838882,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.43678531,
#      'lng': 103.838882}],
#    'distance': 9128,
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['lelong lelong']},
#   'categories': [{'id': '4bf58dd8d48988d1ff941735',
#     'name': 'Miscellaneous Shop',
#     'pluralName': 'Miscellaneous Shops',
#     'shortName': 'Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4f3c4f05e4b085c2d8999846',
#   'name': 'Fernvale butcher and poultry(Halal)',
#   'location': {'lat': 1.391811128657146,
#    'lng': 103.87759430918543,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.391811128657146,
#      'lng': 103.87759430918543}],
#    'distance': 7531,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d11d951735',
#     'name': 'Butcher',
#     'pluralName': 'Butchers',
#     'shortName': 'Butcher',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '56e2940fcd10440088d5305a',
#   'name': 'Halal Frozen Food',
#   'location': {'lat': 1.3154757,
#    'lng': 103.89597,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3154757,
#      'lng': 103.89597}],
#    'distance': 9690,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '56aa371be4b08b9a8d573550',
#     'name': 'Food Service',
#     'pluralName': 'Food Services',
#     'shortName': 'Food Service',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '59561b48033693555b46b641',
#   'name': 'Qtech Cafe Coffee & Tea Halal Restaurant',
#   'location': {'address': '211 Syed Alwi Road',
#    'lat': 1.3078441815854558,
#    'lng': 103.85762080550192,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3078441815854558,
#      'lng': 103.85762080550192}],
#    'distance': 6933,
#    'postalCode': '207744',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['211 Syed Alwi Road', '207744']},
#   'categories': [{'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'shortName': 'American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '429890913'},
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4c92f7fad2e1a1436938cf26',
#   'name': 'halal bakery',
#   'location': {'lat': 1.319245,
#    'lng': 103.89418,
#    'labeledLatLngs': [{'label': 'display', 'lat': 1.319245, 'lng': 103.89418}],
#    'distance': 9318,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d1bc941735',
#     'name': 'Cupcake Shop',
#     'pluralName': 'Cupcake Shops',
#     'shortName': 'Cupcakes',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '4faf29dee4b01cbf307ccd3f',
#   'name': 'Halal tcm',
#   'location': {'lat': 1.3176262635322167,
#    'lng': 103.89882017629914,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.3176262635322167,
#      'lng': 103.89882017629914}],
#    'distance': 9861,
#    'cc': 'SG',
#    'country': 'Singapore'},
#   'categories': [{'id': '4bf58dd8d48988d10f951735',
#     'name': 'Pharmacy',
#     'pluralName': 'Pharmacies',
#     'shortName': 'Pharmacy',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False},
#  {'id': '5871e0ea3731812c07bc6783',
#   'name': 'Noosh Halal Noodle Bar & Grill',
#   'location': {'address': '#01-13B Esplanade Mall',
#    'crossStreet': '8 Raffles Avenue',
#    'lat': 1.289529819986258,
#    'lng': 103.8565092792591,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 1.289529819986258,
#      'lng': 103.8565092792591}],
#    'distance': 8576,
#    'postalCode': '039802',
#    'cc': 'SG',
#    'city': 'Singapore',
#    'country': 'Singapore',
#    'formattedAddress': ['#01-13B Esplanade Mall (8 Raffles Avenue)',
#     '039802']},
#   'categories': [{'id': '52e81612bcbc57f1066b79ff',
#     'name': 'Halal Restaurant',
#     'pluralName': 'Halal Restaurants',
#     'shortName': 'Halal',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1628309638',
#   'hasPerk': False}]

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                                    name  \
# 0  4cb944634c60a0934ef03eca  Air Pasang Nasi Campur & Halal Seafood
# 1  4c258a4bf1272d7f071d85c5                       Sushi Hey - Halal
# 2  4cf9b1c37f2db1f7490723d4                      Chicken Rice Halal
# 3  4cfb5c40ee9cb60ce0f48fad          Cahaya Murni Halal Muslim Food
# 4  4d3969a0687ca35da50a7fc4                   Kedai Kopi Halal Cafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1628309638    False
# 1                                                 []  v-1628309638    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628309638    False
# 3  [{'id': '52e81612bcbc57f1066b79ff', 'name': 'H...  v-1628309638    False
# 4  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1628309638    False
#
#                   location.address  location.lat  location.lng  \
# 0  374 Bukit Batok St. 31, #01-192      1.357655    103.750220
# 1        Sembawang Shopping Centre      1.367412    103.825184
# 2             Blk46-1 tanglin halt      1.298847    103.798165
# 3        #05-91/92, Far East Plaza      1.307399    103.833361
# 4                     IMM Building      1.335175    103.747203
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 1.357654617148932...               7710
# 1  [{'label': 'display', 'lat': 1.367411601858592...               1309
# 2  [{'label': 'display', 'lat': 1.298846504258379...               6906
# 3  [{'label': 'display', 'lat': 1.307398869751881...               5744
# 4  [{'label': 'display', 'lat': 1.335175158127557...               8407
#
#   location.postalCode location.cc location.city location.country  \
# 0              650374          SG     Singapore        Singapore
# 1                 NaN          SG           NaN        Singapore
# 2                 NaN          SG           NaN        Singapore
# 3              228213          SG     Singapore        Singapore
# 4                 NaN          SG     Singapore        Singapore
#
#                            location.formattedAddress  location.crossStreet  \
# 0          [374 Bukit Batok St. 31, #01-192, 650374]                   NaN
# 1                        [Sembawang Shopping Centre]                   NaN
# 2                             [Blk46-1 tanglin halt]                   NaN
# 3  [#05-91/92, Far East Plaza (14 Scotts Rd), 228...          14 Scotts Rd
# 4              [IMM Building (2 Jurong East St. 21)]  2 Jurong East St. 21
#
#   location.neighborhood venuePage.id
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
df_sg = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sg['categories'] = df_sg.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sg.columns = [column.split('.')[-1] for column in df_sg.columns]

df_sg
# Out:
#                                                  name           categories  \
# 0              Air Pasang Nasi Campur & Halal Seafood           Food Court
# 1                                   Sushi Hey - Halal                 None
# 2                                  Chicken Rice Halal          Coffee Shop
# 3                      Cahaya Murni Halal Muslim Food     Halal Restaurant
# 4                               Kedai Kopi Halal Cafe     Asian Restaurant
# 5                                    Global Halal Hub      Warehouse Store
# 6                                       Os Halal Food                 None
# 7                  Happy Family Pasta & Pizza (halal)                 None
# 8                                        Halal Guy,NY                 None
# 9                                  Sakura Halal Food*    Indian Restaurant
# 10                       Halal Nasi Padang Coffeeshop          Coffee Shop
# 11                                         Halal Zone               Hostel
# 12                                A-la Mak Halal Menu     Asian Restaurant
# 13                                 Halal Thai Chinese     Asian Restaurant
# 14                            Halal Hot & Cold Drinks          Coffee Shop
# 15                          Halal Foods International             Pharmacy
# 16                                  Halal Muslim Food                 None
# 17                         Daging Dendeng Halal Sedap                 None
# 18                                      Halal Seafood   Seafood Restaurant
# 19  Halal Goods International @ Quartz industrial ...                 None
# 20                       Halal Bbq Seafood @ Beach Rd          Coffee Shop
# 21                      Halal Cookhouse @ Khatib Camp                Diner
# 22                                         Halal Cafe                 None
# 23                                  Halal  Wet Market   Miscellaneous Shop
# 24                Fernvale butcher and poultry(Halal)              Butcher
# 25                                  Halal Frozen Food         Food Service
# 26           Qtech Cafe Coffee & Tea Halal Restaurant  American Restaurant
# 27                                       halal bakery         Cupcake Shop
# 28                                          Halal tcm             Pharmacy
# 29                     Noosh Halal Noodle Bar & Grill     Halal Restaurant
#
#                                         address       lat         lng  \
# 0               374 Bukit Batok St. 31, #01-192  1.357655  103.750220
# 1                     Sembawang Shopping Centre  1.367412  103.825184
# 2                          Blk46-1 tanglin halt  1.298847  103.798165
# 3                     #05-91/92, Far East Plaza  1.307399  103.833361
# 4                                  IMM Building  1.335175  103.747203
# 5                                    750 #01-07  1.332606  103.891135
# 6                      101 Bedok Reservoir Road  1.333446  103.909303
# 7   Toa Payoh lorong 2, above wet market #02-39  1.338250  103.844749
# 8                                           NaN  1.320566  103.842553
# 9                                           NaN  1.317606  103.825733
# 10                                          NaN  1.317567  103.843520
# 11                                          NaN  1.375567  103.872351
# 12                                          NaN  1.386452  103.829315
# 13                               Far East Plaza  1.306254  103.834422
# 14            #01-06, Yishun Park Hawker Centre  1.424577  103.845022
# 15                                          NaN  1.307283  103.851435
# 16                                          NaN  1.361233  103.747590
# 17                                          NaN  1.389347  103.808729
# 18                                   Lau pa sat  1.280946  103.854189
# 19                                          NaN  1.333303  103.881867
# 20                                   Beach Road  1.301304  103.857719
# 21                                          NaN  1.426283  103.827826
# 22                                          NaN  1.335842  103.746931
# 23                                lelong lelong  1.436785  103.838882
# 24                                          NaN  1.391811  103.877594
# 25                                          NaN  1.315476  103.895970
# 26                           211 Syed Alwi Road  1.307844  103.857621
# 27                                          NaN  1.319245  103.894180
# 28                                          NaN  1.317626  103.898820
# 29                       #01-13B Esplanade Mall  1.289530  103.856509
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 1.357654617148932...      7710     650374
# 1   [{'label': 'display', 'lat': 1.367411601858592...      1309        NaN
# 2   [{'label': 'display', 'lat': 1.298846504258379...      6906        NaN
# 3   [{'label': 'display', 'lat': 1.307398869751881...      5744     228213
# 4   [{'label': 'display', 'lat': 1.335175158127557...      8407        NaN
# 5   [{'label': 'display', 'lat': 1.332605716138659...      8425     469000
# 6   [{'label': 'display', 'lat': 1.333445992672062...     10335     470101
# 7   [{'label': 'display', 'lat': 1.33825, 'lng': 1...      3507        NaN
# 8   [{'label': 'display', 'lat': 1.320566, 'lng': ...      4809        NaN
# 9   [{'label': 'display', 'lat': 1.317606473936739...      4451        NaN
# 10  [{'label': 'display', 'lat': 1.317566982265275...      5149        NaN
# 11  [{'label': 'display', 'lat': 1.375566515676135...      6230        NaN
# 12  [{'label': 'display', 'lat': 1.386452, 'lng': ...      3444     787571
# 13  [{'label': 'display', 'lat': 1.306253548775494...      5899        NaN
# 14  [{'label': 'display', 'lat': 1.424577, 'lng': ...      8029        NaN
# 15  [{'label': 'display', 'lat': 1.307282676451107...      6587        NaN
# 16  [{'label': 'display', 'lat': 1.361233, 'lng': ...      8015        NaN
# 17  [{'label': 'display', 'lat': 1.389347455088877...      3783        NaN
# 18  [{'label': 'display', 'lat': 1.280946, 'lng': ...      9315        NaN
# 19  [{'label': 'display', 'lat': 1.333303166666666...      7429        NaN
# 20  [{'label': 'display', 'lat': 1.301304477332556...      7528        NaN
# 21  [{'label': 'display', 'lat': 1.426283, 'lng': ...      7756        NaN
# 22  [{'label': 'display', 'lat': 1.335841723615632...      8415        NaN
# 23  [{'label': 'display', 'lat': 1.43678531, 'lng'...      9128        NaN
# 24  [{'label': 'display', 'lat': 1.391811128657146...      7531        NaN
# 25  [{'label': 'display', 'lat': 1.3154757, 'lng':...      9690        NaN
# 26  [{'label': 'display', 'lat': 1.307844181585455...      6933     207744
# 27  [{'label': 'display', 'lat': 1.319245, 'lng': ...      9318        NaN
# 28  [{'label': 'display', 'lat': 1.317626263532216...      9861        NaN
# 29  [{'label': 'display', 'lat': 1.289529819986258...      8576     039802
#
#     cc       city    country  \
# 0   SG  Singapore  Singapore
# 1   SG        NaN  Singapore
# 2   SG        NaN  Singapore
# 3   SG  Singapore  Singapore
# 4   SG  Singapore  Singapore
# 5   SG  Singapore  Singapore
# 6   SG  Singapore  Singapore
# 7   SG  Singapore  Singapore
# 8   SG        NaN  Singapore
# 9   SG        NaN  Singapore
# 10  SG        NaN  Singapore
# 11  SG        NaN  Singapore
# 12  SG        NaN  Singapore
# 13  SG        NaN  Singapore
# 14  SG  Singapore  Singapore
# 15  SG  Singapore  Singapore
# 16  SG  Singapore  Singapore
# 17  SG        NaN  Singapore
# 18  SG        NaN  Singapore
# 19  SG        NaN  Singapore
# 20  SG        NaN  Singapore
# 21  SG        NaN  Singapore
# 22  SG        NaN  Singapore
# 23  SG  Singapore  Singapore
# 24  SG        NaN  Singapore
# 25  SG        NaN  Singapore
# 26  SG  Singapore  Singapore
# 27  SG        NaN  Singapore
# 28  SG        NaN  Singapore
# 29  SG  Singapore  Singapore
#
#                                      formattedAddress           crossStreet  \
# 0           [374 Bukit Batok St. 31, #01-192, 650374]                   NaN
# 1                         [Sembawang Shopping Centre]                   NaN
# 2                              [Blk46-1 tanglin halt]                   NaN
# 3   [#05-91/92, Far East Plaza (14 Scotts Rd), 228...          14 Scotts Rd
# 4               [IMM Building (2 Jurong East St. 21)]  2 Jurong East St. 21
# 5           [750 #01-07 (Viva Business Park), 469000]    Viva Business Park
# 6                  [101 Bedok Reservoir Road, 470101]                   NaN
# 7       [Toa Payoh lorong 2, above wet market #02-39]                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                           [787571]                   NaN
# 13                                   [Far East Plaza]                   NaN
# 14  [#01-06, Yishun Park Hawker Centre (51 Yishun ...   51 Yishun Avenue 11
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                                NaN                   NaN
# 18                                       [Lau pa sat]                   NaN
# 19                                                NaN                   NaN
# 20                                       [Beach Road]                   NaN
# 21                                                NaN                   NaN
# 22                                                NaN                   NaN
# 23                                    [lelong lelong]                   NaN
# 24                                                NaN                   NaN
# 25                                                NaN                   NaN
# 26                       [211 Syed Alwi Road, 207744]                   NaN
# 27                                                NaN                   NaN
# 28                                                NaN                   NaN
# 29  [#01-13B Esplanade Mall (8 Raffles Avenue), 03...      8 Raffles Avenue
#
#    neighborhood                        id
# 0           NaN  4cb944634c60a0934ef03eca
# 1           NaN  4c258a4bf1272d7f071d85c5
# 2           NaN  4cf9b1c37f2db1f7490723d4
# 3           NaN  4cfb5c40ee9cb60ce0f48fad
# 4           NaN  4d3969a0687ca35da50a7fc4
# 5           NaN  53a388b3498e92f6ecde8307
# 6           NaN  4bc0153d920eb7130e91182c
# 7           NaN  4d5cad919c31b60c59b9b7ee
# 8           NaN  54c88b6e498e5fd8bb51450d
# 9           NaN  5104ad75e4b073eb9b199318
# 10          NaN  4d648d44823ca35d9470f588
# 11          NaN  4ecdc716f790d070358362ff
# 12          NaN  4cb691f58db0a143cd2c6b16
# 13          NaN  4ef309f25c5cd8c3b324c0cf
# 14       Yishun  5c4b083cb6eedb002cc59f92
# 15          NaN  4e2254b952b1f82ffba8a533
# 16          NaN  4de98c4445dd3993a874e5e5
# 17          NaN  4d522b76bd6ff04d8e5cf90c
# 18          NaN  4d2973a03c795481621dd89b
# 19          NaN  4d7ee0c1b25d6dcb9bb5c242
# 20          NaN  4f27bdfde4b0cec78dbba56a
# 21          NaN  4d57ac23de8f6dcb62e80191
# 22          NaN  4cbaf1a6adcd548107ef25a2
# 23          NaN  4cb124feeb65b1f7f39372cd
# 24          NaN  4f3c4f05e4b085c2d8999846
# 25          NaN  56e2940fcd10440088d5305a
# 26          NaN  59561b48033693555b46b641
# 27          NaN  4c92f7fad2e1a1436938cf26
# 28          NaN  4faf29dee4b01cbf307ccd3f
# 29          NaN  5871e0ea3731812c07bc6783

# %%
venues_map = folium.Map(location=[latitude_sg, longitude_sg], zoom_start=13) # generate map centred around central Singapore

# add a red circle marker to represent central Singapore
folium.CircleMarker(
    [latitude_sg, longitude_sg],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Halal restaurants as blue circle markers
for lat, lng, label in zip(df_sg.lat, df_sg.lng, df_sg.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_a952c37ccddb4e52a81e602f4a670ec5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a952c37ccddb4e52a81e602f4a670ec5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a952c37ccddb4e52a81e602f4a670ec5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_a952c37ccddb4e52a81e602f4a670ec5%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
for data in df_sg.index:
    categories = df_sg['categories'][data]
    #neighborhood = dataframe_filtered['Neighbourhood'][data]

# %%
import re
#restaurant_string = 'Restaurant'
#restaurant_string.find('Restaurant')

# Create a new column as Label and get the data from 'categories' as integer
#for .....
#s1 = dataframe_filtered.iloc[0]

#s1.str.contains('Restaurant')
#res = [sub.replace('4', '1') for sub in test_list]

#error with restaurant loc string
df_sg['Label']=df_sg['categories'].replace(to_replace=['Food Court', 'Coffee Shop', r'(^.*Restaurant.*$)', 'None', np.nan],value=[1,2,3,4,5],inplace=False)
df_sg.head()
# Out:
#                                      name        categories  \
# 0  Air Pasang Nasi Campur & Halal Seafood        Food Court
# 1                       Sushi Hey - Halal              None
# 2                      Chicken Rice Halal       Coffee Shop
# 3          Cahaya Murni Halal Muslim Food  Halal Restaurant
# 4                   Kedai Kopi Halal Cafe  Asian Restaurant
#
#                            address       lat         lng  \
# 0  374 Bukit Batok St. 31, #01-192  1.357655  103.750220
# 1        Sembawang Shopping Centre  1.367412  103.825184
# 2             Blk46-1 tanglin halt  1.298847  103.798165
# 3        #05-91/92, Far East Plaza  1.307399  103.833361
# 4                     IMM Building  1.335175  103.747203
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 1.357654617148932...      7710     650374  SG
# 1  [{'label': 'display', 'lat': 1.367411601858592...      1309        NaN  SG
# 2  [{'label': 'display', 'lat': 1.298846504258379...      6906        NaN  SG
# 3  [{'label': 'display', 'lat': 1.307398869751881...      5744     228213  SG
# 4  [{'label': 'display', 'lat': 1.335175158127557...      8407        NaN  SG
#
#         city    country                                   formattedAddress  \
# 0  Singapore  Singapore          [374 Bukit Batok St. 31, #01-192, 650374]
# 1        NaN  Singapore                        [Sembawang Shopping Centre]
# 2        NaN  Singapore                             [Blk46-1 tanglin halt]
# 3  Singapore  Singapore  [#05-91/92, Far East Plaza (14 Scotts Rd), 228...
# 4  Singapore  Singapore              [IMM Building (2 Jurong East St. 21)]
#
#             crossStreet neighborhood                        id  \
# 0                   NaN          NaN  4cb944634c60a0934ef03eca
# 1                   NaN          NaN  4c258a4bf1272d7f071d85c5
# 2                   NaN          NaN  4cf9b1c37f2db1f7490723d4
# 3          14 Scotts Rd          NaN  4cfb5c40ee9cb60ce0f48fad
# 4  2 Jurong East St. 21          NaN  4d3969a0687ca35da50a7fc4
#
#               Label
# 0                 1
# 1                 5
# 2                 2
# 3  Halal Restaurant
# 4  Asian Restaurant

# %%
#Setting the cluster number as number of labels
kclusters=len(df_sg.Label.unique())

# create map
map_sg = folium.Map(location=[latitude_sg, longitude_sg], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


# add markers to the map
markers_colors = []
for categories in zip(df_sg['Label']):
    label = '{}'.format(categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [latitude_sg, longitude_sg],
        radius=5,
        popup=label,
        color=rainbow[categories],
        fill=True,
        fill_color=rainbow[categories-1],
        fill_opacity=0.7).add_to(map_sg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-6bac5fc4781a> in <module>
#      21         radius=5,
#      22         popup=label,
# ---> 23         color=rainbow[categories],
#      24         fill=True,
#      25         fill_color=rainbow[categories-1],
#
# TypeError: list indices must be integers or slices, not tuple

# %%
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_2292aef27002441ca5d0140feee1969b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2292aef27002441ca5d0140feee1969b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2292aef27002441ca5d0140feee1969b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_2292aef27002441ca5d0140feee1969b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B1.357107%2C103.8194992%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
#For 'explore' Foursquare feature 
'There are {} around Singapore.'.format(len(results['response']['location'][0]['items']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f58aa6e2f296> in <module>
# ----> 1 'There are {} around Singapore.'.format(len(results['response']['groups'][0]['items']))
#
# KeyError: 'groups'
